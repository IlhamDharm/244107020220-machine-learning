# %% [markdown]
# <a href="https://colab.research.google.com/github/ianmen10/244107020220-machine-learning/blob/main/TG1_244107020220_ILHAM_DHARMA_ATMAJA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mne
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 58.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.3.1 which is incompatible.
# ...

# %%
# !pip install pyprep scipy wandb pyecg
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip install scikit-learn
# !pip install pyprep scipy wandb pyecg --no-build-isolation
# Out:
# ...
#   Using cached pyprep-0.9.0-py3-none-any.whl.metadata (7.9 kB)
# ...
#   Using cached pyECG-0.0.9.1-py2.py3-none-any.whl.metadata (3.1 kB)
# ...
#   Using cached ishneholterlib-2017.4.11.tar.gz (7.0 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached wfdb-2.2.1.tar.gz (94 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached pytest_cov-7.1.0-py3-none-any.whl.metadata (32 kB)
# ...
#   Using cached pycrc-0.11.0-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached nose-1.3.7-py3-none-any.whl.metadata (1.7 kB)
# ...
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# ...

# %%
# !pip install pyprep scipy wandb
# !pip install pyecg --no-deps
# Out:
# ...
#   Using cached pyprep-0.9.0-py3-none-any.whl.metadata (7.9 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 1.5 MB/s eta 0:00:00
# ...
#   Using cached pyECG-0.0.9.1-py2.py3-none-any.whl.metadata (3.1 kB)
# ...

# %% [markdown]
# **BAGIAN 1**
# Kgunaan dari masing masing library
#
#
# *  pyPREP duigunakan untuk melakukan preprocessing otomats pada dat sinyal EEG (Elerktroencephalogram)
# *   Scipy yaitu pustaka komputasi ilmiah untuk matematika, aljabar linier, optimasi, dan pemrosesan sinyal
# *  wandb (Weights & Biases) adalah alat untuk melacak eksperimen machine learning, visualisasi metrik, dan manajemen model
# * pyECG yaitu pustkann untuk memproses dan menganalisis sinyal EKG (Electrocardiogram/aktivitas listrik jantung)

# %% [markdown]
# **BAGIAN 2**
# 1. Contoh pelanggaran etika dan hukum penggunaan AI
# * kasus:Pengguanaan teknologi deepfake untuk memalsukan identitas seseorang dalam video demi kepentingan penipuasn atau pencemaran nama baik
# * Referensi:Undang-Undang Informasi dan Transaksi Elektronik (UU ITE) serta regulasi pelindungan data pribasi (UU PDP)
#
# 2. Dampak energi & Lingkungan serta cara mengatasinya
# * Dampak:Pelatihan model deep learning skla besar mengonsumsi daya listrik masif dari pusat data , sehingga meningkatkan emisi karbon global
# * Solusinya bisa menerapkan Green AI dengan mengoptimalkan arsitektur modl agar lebih ringan, menggunakan teknik transfer learning serta memindahkan komputasi ke fasilitas data center yang menggunakan energi terbarukan
# * referensi:Strubell et al. (2019), "Energy and Policy Considerations for Deep Learning in NLP"
